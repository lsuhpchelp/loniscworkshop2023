# %% [markdown]
# <a href="https://colab.research.google.com/github/lsuhpchelp/loniscworkshop2023/blob/main/day3-4/2023_gradient_descent_y_fx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This Jupyter notebook will help you understand the gradient descent process by finding the minimum value of a given object function $f(x)=(x-1)^2$ within the range of $[0,2]$

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import rc
#rc('animation', html='jshtml')

# %% [markdown]
# ## This is the object function we want to minimize $f(x)=(x-1)^2$, the argument is a vector, so think about what numpy function we are using?

# %%
# object function
def f(x):
    return (x-1)**2;

# %% [markdown]
# ## Try to fill in the derivative of $f(x)$:

# %%
# calculate the derivative of f(x)
def df(x):
    # what is the derivative of f(x), replace "0" with the derivative of f(x) ?
    return 0;

# %% [markdown]
# ## Solution
# Check the below cell for solution:

# %%
## calculate the derivative of f(x)
#def df(x):
#    # what is the derivative of f(x) ?
#    return 2*(x-1);

# %% [markdown]
# ## Here we define the gradient descent function:

# %%
def gradient_descent(start_at=np.random.uniform(-1,1), 
                     iterations=20, 
                     learning_rate=0.1):
    # record all intermediate values    
    x_vals, y_vals = [], []
    print("start_at=", start_at)
    x = start_at
    x_vals.append(x)
    y_vals.append(f(x))
    for _ in range(iterations):
        gradient = df(x) # derivative of f(x)
        x += learning_rate * -gradient
        y = f(x)
        x_vals.append(x)
        y_vals.append(y)
        #plt.scatter(x, y, color='grey', edgecolor='black', zorder=3)
    return x_vals, y_vals

# %% [markdown]
# ## Call the gradient descent function from here:

# %%
xv, yv = gradient_descent(start_at = np.random.uniform(2,2), iterations = 30, learning_rate=0.1)
#print(xv)
#print(yv)
# Out:
# start_at= 2.0

# %%
#from ipywidgets import interact
#interact(gradient_descent, 
#         start_at=(0,np.pi,0.5), 
#         iterations=(1,20,1), 
#         learning_rate=(0.05,0.96,0.05),
#         __output_result=False);

# %% [markdown]
# ##   This will display the initial condition.

# %%
fig, ax = plt.subplots()

t = np.arange(0,2.0, 0.01)
s = f(t)
l = plt.plot(t, s)

#redDot, = plt.plot([0], [f(0)], 'ro')
redDot, = plt.plot([xv[0]], [f(xv[0])], 'ro')
def animate(i):
    # redDot.set_data(i, np.sin(i))
    redDot.set_data(i, f(i))
    return redDot,

# create animation using the animate() function
#myAnimation = animation.FuncAnimation(fig, animate, frames=xv, \
#                                      interval=200, blit=False, repeat=False)

# %% [markdown]
# ## Visualize the gradient descent procedure

# %%
# create animation using the animate() function
myAnimation = animation.FuncAnimation(fig, animate, frames=xv, \
                                      interval=800, blit=False, repeat=False)
rc('animation', html='jshtml')
myAnimation
# Out:
# <ipython-input-8-61744aea6c8b>:11: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   redDot.set_data(i, f(i))
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
# ...

# %% [markdown]
# ## Save the animation to a gif file. You can download the gradient_descent.gif and view it on your desktop or laptop.

# %%
myAnimation.save('gradient_descent.gif', writer = "pillow", fps=100 )
# Out:
# <ipython-input-8-61744aea6c8b>:11: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   redDot.set_data(i, f(i))
